# %%
Gemini_API_KEY = "AIzaSyBhzDjXnH_dLxZRbLuXV9ZgMoH8MGszQlA"

# %%
import google.generativeai as genai
import os

# ✅ API 키 설정
genai.configure(api_key=Gemini_API_KEY)

# ✅ 사용 가능한 모델 목록 조회
models = genai.list_models()
for model in models:
    print(model.name, "➡", model.supported_generation_methods)
# Out:
# models/chat-bison-001 ➡ ['generateMessage', 'countMessageTokens']
# models/text-bison-001 ➡ ['generateText', 'countTextTokens', 'createTunedTextModel']
# models/embedding-gecko-001 ➡ ['embedText', 'countTextTokens']
# models/gemini-1.0-pro-vision-latest ➡ ['generateContent', 'countTokens']
# models/gemini-pro-vision ➡ ['generateContent', 'countTokens']
# models/gemini-1.5-pro-latest ➡ ['generateContent', 'countTokens']
# models/gemini-1.5-pro-001 ➡ ['generateContent', 'countTokens', 'createCachedContent']
# models/gemini-1.5-pro-002 ➡ ['generateContent', 'countTokens', 'createCachedContent']
# models/gemini-1.5-pro ➡ ['generateContent', 'countTokens']
# models/gemini-1.5-flash-latest ➡ ['generateContent', 'countTokens']
# models/gemini-1.5-flash-001 ➡ ['generateContent', 'countTokens', 'createCachedContent']
# models/gemini-1.5-flash-001-tuning ➡ ['generateContent', 'countTokens', 'createTunedModel']
# models/gemini-1.5-flash ➡ ['generateContent', 'countTokens']
# ...

# %%
input_text = "한국은행은 계염이 터졌던 2024년 4분기의 GDP 증가율을 그 전 분기에 대비해서 0.5% 늘어날 것이라고 예상을 했었어요. 그런데 얼마 전에 실제로 나온 증가율을 보니까 0.1%에 그쳤습니다. 0.4%포인트 차이가 나는 거죠. 이에 대해 한국은행은 예상치 못했던 정치적 혼란 때문이라고 밝혔습니다. 지난 4분기 석 달간의 gdp가 한 600조 정도 됐었기 때문에 이 차이가 나는 0.4%포인트의 액수가 2조 4천억 원이다라는 계산이 나옵니다. 요만큼의 이 계엄 선포로 인해서 우리가 지난 4분기, 즉 석 달 동안 손해분이다 라는 얘기가 경제학자대사에서 나오고 있어요. 그런데 이게 이렇게만 보기에는 좀 너무 한정적이다 라는 얘기도 나옵니다. 포브스가 얘기했듯이 두고두고 갚아야 하는 청구서가 지금 계속해서 날아오고 있는 모양새가 현실화가 되고 있기 때문이에요. 귀에 빡 박히는 이슈 맛집 귀에 빡 종원입니다. 지난편에 이어서 오늘 본격적으로 우리 경제가 겪어야 하는 비용을 따져보도록 하겠습니다. 그냥 단순히 gdp를 놓고 계산한 거 말고 이걸 좀 어떻게 구체적으로 카테고리를 나눠서 실제로 우리가 얼마의 비용을 지불을 하고 있는가를 한번 전문가들과 계산을 해봤어요. 정부 국무조정실이 단국대학교와 함께 사회적 갈등의 연구해 본 적이 있습니다. 비용 산출은 어떻게 했냐면 갈등으로 인한 생산 손실, 각종 집회비용, 국민들의 심리적 비용, 그리고 이걸 관리하기 위한 공권력의 , 또 재판비용 등등등 굉장히 세부적으로 나눠가지고 경제적으로 액수를 계산을 했거든요. 연구에 따르면 2013년부터 2022년까지 10년간 2326 6000억원의 경제적 손실을 사회적 갈등으로 보았다. 연간으로 따지면 232조가 되겠죠, 평균. 2023년 당시 우리나라 GDP가 2200조였으니까 연간 GDP의 10%에 달하는 지출을 하고 있다. 특이할 점은 인한 비용이 2010년부터 굉장히 급격하게 증가하는 모습을 볼 수 있습니다. 특히 그중에서도 대선이 있던 2017 한 해의 유독 더 급증을 하는데 이때 해에만 비용이 1700조가 넘었다 라고 연구 보고서가 밝히고 있거든요 이번 비상계엄 사태로 갈등은 이때보다도 훨씬 더 심한 것으로 여러 가지 지표에서 나타나고 있기 때문에 늘어날 것이다 얘기가 나오고 KDI에서 우리 경제 불확실성 지수라는 것을 공표하는데 박근혜 탈레드가 250 정도였어요 작년 12월이 500입니다 두 배나 차이나요 그리고 보통 이제 프락시타가 생기면 제일 먼저 생기는 게 소비 위축 쪽인데 소비 심리 지수가 이번에 13포인트가 떨어져 가지고 그 심리 지수를 작성한 일에 두 번째로 큰 수치였거든요 수출도 어렵지만 지금 내수 시장의 침체가 심각한 수준입니다 수출과 달리 내수 시장은 혼란, 정치적 혼란이 큰 영향을 미치는 분야거든요 그래서인지 우리나라의 위축 정도가 코로나 사태가 터진 이후 최저치를 찍었다고 있고요 100 밑으로 떨어지면 심리가 많이 움츠러들었다는 지표인데 이게 2016, 2017 박근혜 전 대통령 탄핵 당시에도 움츠러들었었거든요 이번에 개염 선포가 된 이후에는 그때보다도 훨씬 심하게 움츠러들었습니다 이러다 보니까 자연스럽게 시장에서 소매 판매액은 2003 카드 대란 이후에 21 만에 최악으로 쪼그라들었다라는 집계가 나왔죠. 전년도에 비해서 소매 판매지수가 2.2% 감소를 했습니다. 2023년에 우리나라 시장 규모가 510 원 정도 됐습니다. 그냥 정말 단순하게 데이터로만 개선하면 1 사이에 시장에 돌던 돈 약 11조에서 12 원 정도가 날아갔다라는 계산이 . 이렇게 곳곳이 얼어붙다 얼마 전에 발표된 고용지표는 정말 말 그대로 최악이었습니다. 3명이 일자리 하나를 못 구한다라는 결과가 나왔는데 왜 심각하냐 하면 경제적 어려움을 겪고 있는 나라가 많은데 이렇게까지 일자리가 심각하진 않거든요. 이러다 진짜 우리나라가 완벽하게 한파, 경제 한파에 접어들었구나 . 갈등 안에 여러 가지 카테고리가 . 계층, 지역, 환경, 노동, 이념 이런 식으로 카테고리를 나눴는데 중에서도 압도적인 차지하는 게 이념 갈등이었습니다. 재미있는 건 전체 갈등의 빈도로만 따지면 갈등은 6%밖에 되지 않았는데 비용으로 환산하면 다 합친 것보다도 많은 토네로 사회에 돌아온다라는 연구결과라는 것이죠. 진영에 따른 갈등 거기에다가 이제 최근에는 부정선거 논란까지 더해지면서 갈등이 극대화되고 있는데 가장 대가가 갈등을 겪고 있다라는 얘기를 할 수가 대표적인 얘가 치솟은 환율이죠 달러 인덱스라는 달러 인덱스는 달러의 가치가 다른 나라 환율에 비해서 얼마인가를 나타내는 지수인데 개염이 선포되기 전날인 12월 2일을 기준으로 제가 녹화를 최근까지를 따져봤을 때 1.3% 올랐습니다 환율은 같은 기간 얼마가 올랐나를 봤을 때 4.2% 올랐습니다. 즉 자체의 가치가 오른 것보다 대비 원화 환율이 많이 오른 거죠. 장기적으로 주식시장도 갈등이 앞으로 심화가 된다면 타격을 받을 수 있다 점에서 손실이 더더욱 커질 수밖에 없다라는 우려가 지점입니다. 일단 뭐 정부 기능이 마비가 돼 있지 않습니까? 탄핵 심판이 나오기 전까지는 거의 대부분의 부처가 예산 집행을 잘 못하고 . 당장 시급한 프로젝트들까지 전부 올스탑을 하다 이로 추산해보는 많을 것이다 . 그런가 하면 대내적으로 중에 부정선거 논란이 있지 않습니까? 그래서 매 선거 때마다 새로운 어떤 보강 조치들이 . 대표적으로 선관위에 보안이 취약하다는 국정원의 지적이 나온 이후에는 전문 보안업체와 시스템을 업데이트하고 비밀번호도 3중 4중 보안망으로 바꿨고요. 총선부터는 인력을 대규모로 추가 투입해가지고 수건표 과정을 처음으로 도입을 했습니다. 사전투표함을 24시간 CCTV로 볼 시스템을 갖추기도 했죠. 매번 선거를 할 때마다 미비한 점이 나오면 보안하기 위해서 그게 얼마가 됐든 예산을 투입하는 건 너무나 당연한 일이고 그렇게 해야만 합니다. 왜냐하면 선거라는 사회 시스템에 대한 신뢰이기 때문이죠. 골이 워낙에 깊어지다 행정 아무리 쏟아 부어도 해결이 불가능해 보이는 영역으로까지 의심의 눈초리가 커지고 있고 어떤 요구를 목소리가 높아진다는 문제입니다. 최근에는 선관위에 서버를 다 공개해라 이런 요구가 있는데 근데 요건 힘들다고 합니다. 만약에 서버 전체 공개를 서버를 다시 재구축을 해야 되는데 여기에 일단 들어가는 어마어마하다고 하고요. 문제는 비용보다도 안정화하는데 드는 시간이 오래 걸린다고 . 오히려 지금보다 혼란을 초래할 있다라는 것이 중앙선관위의 설명입니다. 그럼에도 불구하고 오히려 커지면 커졌지 작아질 것 같지는 않다 이거 돈을 쓴다고 지금의 불신이 회복이 될 수는 있어? 불안한 목소리가 여기저기서 나오는 . 불안감에 대한 따져봤을 때는 행정적으로 실제 세금을 쓴 비용보다도 클 수밖에 없다. 당장 신용도 자체가 떨어질 있다는 있어요. 세계 3대 신용평가기관이죠. 스탠다드 푸어스 무디스 피치 중에 등급을 가장 낮게 주고 데가 피치입니다. 저는 피치가 제일 걱정이 됐었어요. 피치만 a 등급에서 바닥이었고 스탠다드 푸어스하고 무디스는 a 등급에서 중간 이렇게 되니까 휘치에서는 달 게만 떨어지면 AA등급이 아니라 A등급으로 떨어지는 거거든요. 걱정을 했는데 휘치가 안 바꾸기로 했으니까 다행이긴 하지만 하지만 스탠드아이앤프와 무디스는 , 불확실성, 불확실성들이 점수 항목에 들어가 . 만약에 인용이 된다면 3, 4, 5월에 선거가 일어나지 ? 그때 과연 선거 자체를 부정하는 그런 막 생겨난다. 이때는 이거는 심각하다고 봐야죠. 그때 그러니까 불확실성을 빨리 없애는 영역에서는 중요한 겁니다. 프랑스 같은 경우가 혼란을 이유로 최근에 국가 신용도가 하락을 했거든요. 길을 걷게 힘들어질 벌써부터 . 아까 말씀드렸듯이 gdp의 10% 사회적인 비용으로 지출이 된다라는 정부의 연구 결과가 ? 비용만으로는 설명이 되지 않는 부분이 . 바로 우리나라가 작금의 국제 경쟁에서 완전히 도태될 위기에 처했다라는 겁니다. 산업혁명이 그랬었고 인터넷 시대가 접어들면서 한번 크게 점프를 했고 모바일 시대 젊어들면서 크게 점프를 했고 지금은 AI 시대를 맞이해서 또 시기인데 문제가 미국이나 중국이나 일본 나라는 정부에서 기업에 엄청난 지원을 해주고 ? 근데 혼란으로 인해서 합의가 국회에서 원활하게 되고 않아요. 2000년대 초에 IT 혁명이라고 말하는 있었죠. 우리나라는 했냐? 그걸 탔어요. 돈 엄청 풀었어요. 해야 될 시기에는 일반적인 지원 해서 되는 아니에요. 몰아주는 있어야 되는 . 그게 안 상황이죠. 우리는 중요한 시간들이 하나씩 하나씩 지나가고 상황은 악화되는데 불신은 봉합이 기미가 보이지 않고 . 제가 관련 아이템들을 계속 다루다 좋은 소리가 들리는 분야가 점점 사라져가는 것 같아서 무거운 마음을 갖고 있다가 곧 심판도 날 것이고 다른 정치적인 변역이 올 텐데 힘들어 보이지만 불신을 봉합을 길이 열렸으면 좋겠습니다. 조카 PD는 지식 뉴스 교양이를 부탁해는 여기까지 다이어트도 칼로리 신경 쓰지 말고 드세요. 대신에 키토식을 해보세요. 박종원 스브스 프리미엄 다운로드하세요"

# %%
import google.generativeai as genai
import os

# ✅ 1. Gemini API 키 설정 (main.py에서 불러오기)
genai.configure(api_key=Gemini_API_KEY)

# ✅ 2. 요약 함수 정의
def summarize_text(input_text):
    """
    Google Gemini API를 활용하여 주어진 텍스트를 요약하는 함수
    :param input_text: 요약할 원문 텍스트
    :return: 요약된 결과
    """
    try:
        model = genai.GenerativeModel("models/gemini-1.5-pro-latest")  # ✅ Gemini 모델 선택
        response = model.generate_content(f"다음 내용을 요약해주세요:\n\n{input_text}")
        return response.text  # ✅ 요약된 텍스트 반환
    except Exception as e:
        return f"오류 발생: {str(e)}"

# ✅ 3. 사용 예시
if __name__ == "__main__":    
    summary = summarize_text(input_text)
    
    print(f"📌 원문({len(input_text)}):{input_text}")
    print(f"\n✅ 요약 결과({len(summary)}):{summary}")
# Out:
# 📌 원문(4402):한국은행은 계염이 터졌던 2024년 4분기의 GDP 증가율을 그 전 분기에 대비해서 0.5% 늘어날 것이라고 예상을 했었어요. 그런데 얼마 전에 실제로 나온 증가율을 보니까 0.1%에 그쳤습니다. 0.4%포인트 차이가 나는 거죠. 이에 대해 한국은행은 예상치 못했던 정치적 혼란 때문이라고 밝혔습니다. 지난 4분기 석 달간의 gdp가 한 600조 정도 됐었기 때문에 이 차이가 나는 0.4%포인트의 액수가 2조 4천억 원이다라는 계산이 나옵니다. 요만큼의 이 계엄 선포로 인해서 우리가 지난 4분기, 즉 석 달 동안 손해분이다 라는 얘기가 경제학자대사에서 나오고 있어요. 그런데 이게 이렇게만 보기에는 좀 너무 한정적이다 라는 얘기도 나옵니다. 포브스가 얘기했듯이 두고두고 갚아야 하는 청구서가 지금 계속해서 날아오고 있는 모양새가 현실화가 되고 있기 때문이에요. 귀에 빡 박히는 이슈 맛집 귀에 빡 종원입니다. 지난편에 이어서 오늘 본격적으로 우리 경제가 겪어야 하는 비용을 따져보도록 하겠습니다. 그냥 단순히 gdp를 놓고 계산한 거 말고 이걸 좀 어떻게 구체적으로 카테고리를 나눠서 실제로 우리가 얼마의 비용을 지불을 하고 있는가를 한번 전문가들과 계산을 해봤어요. 정부 국무조정실이 단국대학교와 함께 사회적 갈등의 연구해 본 적이 있습니다. 비용 산출은 어떻게 했냐면 갈등으로 인한 생산 손실, 각종 집회비용, 국민들의 심리적 비용, 그리고 이걸 관리하기 위한 공권력의 , 또 재판비용 등등등 굉장히 세부적으로 나눠가지고 경제적으로 액수를 계산을 했거든요. 연구에 따르면 2013년부터 2022년까지 10년간 2326 6000억원의 경제적 손실을 사회적 갈등으로 보았다. 연간으로 따지면 232조가 되겠죠, 평균. 2023년 당시 우리나라 GDP가 2200조였으니까 연간 GDP의 10%에 달하는 지출을 하고 있다. 특이할 점은 인한 비용이 2010년부터 굉장히 급격하게 증가하는 모습을 볼 수 있습니다. 특히 그중에서도 대선이 있던 2017 한 해의 유독
# ...
